# %%
install.packages("rlang")
install.packages("devtools")
# Out:
# Warning message in install.packages("rlang"):
# “installation of package ‘rlang’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependencies ‘openssl’, ‘zip’, ‘fastmap’, ‘diffobj’, ‘gert’, ‘gh’, ‘processx’, ‘glue’, ‘cachem’, ‘commonmark’, ‘purrr’, ‘brio’, ‘ps’, ‘waldo’, ‘usethis’, ‘callr’, ‘cli’, ‘ellipsis’, ‘fs’, ‘lifecycle’, ‘memoise’, ‘rcmdcheck’, ‘rlang’, ‘roxygen2’, ‘sessioninfo’, ‘testthat’
#
# Warning message in install.packages("devtools"):
# “installation of package ‘openssl’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘zip’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘fastmap’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘diffobj’ had non-zero exit status”Warning message in install.packages("devtools"):
# ...

# %%
install.packages("devtools")
library("devtools")
devtools::install_github("StoreyLab/fFDR")
# Out:
# also installing the dependencies ‘openssl’, ‘zip’, ‘fastmap’, ‘diffobj’, ‘gert’, ‘gh’, ‘processx’, ‘glue’, ‘cachem’, ‘commonmark’, ‘purrr’, ‘brio’, ‘ps’, ‘waldo’, ‘usethis’, ‘callr’, ‘cli’, ‘ellipsis’, ‘fs’, ‘lifecycle’, ‘memoise’, ‘rcmdcheck’, ‘rlang’, ‘roxygen2’, ‘sessioninfo’, ‘testthat’
#
# Warning message in install.packages("devtools"):
# “installation of package ‘openssl’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘zip’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘fastmap’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘diffobj’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘glue’ had non-zero exit status”Warning message in install.packages("devtools"):
# ...

# %%
library(ggplot2)
ggplot(data=iris, aes(x=Sepal.Length, y=Sepal.Width, color=Species)) + geom_point(size=3)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# plot without title

# %%
path="/Users/effiehan/Desktop/term4/swsc/fdr_ratios/cov/"

data_alpha<- read.csv(path+"pos_alpha.csv",header=TRUE, stringsAsFactors=FALSE)
data_p<- read.csv(path+"pos_p.csv",header=TRUE, stringsAsFactors=FALSE)
# Out:
# Error in path + "pos_alpha.csv": non-numeric argument to binary operator
# Traceback:
#
# 1. read.csv(path + "pos_alpha.csv", header = TRUE, stringsAsFactors = FALSE)
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)

# %%
data_alpha
# Out:
# Error in eval(expr, envir, enclos): object 'data_alpha' not found
# Traceback:
